# %%
from roboflow import Roboflow

rf = Roboflow(api_key="qhSk7QdaM3p1YIzIdrPZ")
project = rf.workspace().project("icook")
model = project.version(1).model
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
prediction = model.predict("image_name.jpg")

preds_class = []
for result in prediction.json()['predictions']:
    preds_class.append(result['class'])
    
preds_class
# Out:
# ['potato',
#  'potato',
#  'potato',
#  'potato',
#  'potato',
#  'potato',
#  'Tomato',
#  'Tomato',
#  'potato',
#  'Tomato',
#  'potato',
#  'potato',
#  'Tomato']

# %%
prediction.plot()
prediction.save(output_path="image_name_with_labels.jpg")
